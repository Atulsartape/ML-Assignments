# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:/Users/Admin/Desktop/JN/Breast_cancer_data.csv")
df.head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  842302         M        17.99         10.38           122.8     1001.0
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33            184.6      2019.0            0.1622
# 1  ...          23.41            158.8      1956.0            0.1238
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
#
#    fractal_dimension_worst  Unnamed: 32
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df['Unnamed: 32'].isnull().sum()
# Out:
# np.int64(569)

# %%
df1 = df.drop(['id','Unnamed: 32'],axis='columns')

# %%
df1.isna().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df1['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
sns.histplot(df1['radius_mean'])
# Out:
# <Axes: xlabel='radius_mean', ylabel='Count'>

# %%
Q1 , Q2 = df1['radius_mean'].quantile([0.01,0.99])

# %%
Q1,Q2
# Out:
# (8.458359999999999, 24.37160000000002)

# %%
df2 = df1[(df1['radius_mean'] <= Q2) &  (df1['radius_mean'] >= Q1)]

# %%
df2.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   557.000000    557.000000      557.000000   557.000000
# mean     14.063776     19.243788       91.505691   643.758348
# std       3.256434      4.296501       22.404254   314.017898
# min       8.571000      9.710000       54.090000   221.200000
# 25%      11.710000     16.160000       75.270000   421.000000
# 50%      13.370000     18.820000       86.240000   551.100000
# 75%      15.750000     21.700000      103.700000   773.500000
# max      24.250000     39.280000      166.200000  1761.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       557.000000        557.000000      557.000000           557.000000
# mean          0.096329          0.103477        0.086919             0.048033
# std           0.013966          0.051933        0.076653             0.036717
# min           0.062510          0.019380        0.000000             0.000000
# ...

# %%
sns.histplot(df2['radius_mean'])
# Out:
# <Axes: xlabel='radius_mean', ylabel='Count'>

# %%
sns.histplot(df2['texture_mean'])
# Out:
# <Axes: xlabel='texture_mean', ylabel='Count'>

# %%
Q1 , Q2 = df2['texture_mean'].quantile([0.01,0.99])

# %%
Q1,Q2
# Out:
# (10.9268, 30.663999999999994)

# %%
df3 = df2[(df2['texture_mean'] <= Q2) &  (df2['texture_mean'] >= Q1)]

# %%
sns.histplot(df3['texture_mean'])
# Out:
# <Axes: xlabel='texture_mean', ylabel='Count'>

# %%
df3.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   545.000000    545.000000      545.000000   545.000000
# mean     14.050464     19.182385       91.415927   642.325688
# std       3.252587      3.962854       22.374045   313.204408
# min       8.571000     10.940000       54.090000   221.200000
# 25%      11.740000     16.180000       75.460000   422.900000
# 50%      13.340000     18.820000       86.180000   546.400000
# 75%      15.730000     21.600000      103.400000   766.600000
# max      24.250000     30.620000      166.200000  1761.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       545.000000        545.000000      545.000000           545.000000
# mean          0.096347          0.103453        0.086833             0.047919
# std           0.014024          0.051650        0.076477             0.036609
# min           0.062510          0.019380        0.000000             0.000000
# ...

# %%
sns.histplot(df3['area_worst'])
# Out:
# <Axes: xlabel='area_worst', ylabel='Count'>

# %%
Q1 , Q2 = df3['area_worst'].quantile([0.01,0.99])
Q1,Q2
# Out:
# (279.472, 2400.7999999999997)

# %%
df4 = df3[(df3['area_worst'] <= Q2) &  (df3['area_worst'] >= Q1)]

# %%
df4.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   533.000000    533.000000      533.000000   533.000000
# mean     14.014161     19.186341       91.181989   635.968668
# std       3.105653      3.949881       21.440607   295.529943
# min       8.726000     10.940000       55.270000   230.900000
# 25%      11.750000     16.210000       75.540000   426.700000
# 50%      13.340000     18.820000       86.180000   546.400000
# 75%      15.660000     21.590000      102.800000   758.600000
# max      24.250000     30.620000      166.200000  1761.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       533.000000        533.000000      533.000000           533.000000
# mean          0.096289          0.103586        0.086685             0.047706
# std           0.014097          0.051950        0.076492             0.036203
# min           0.062510          0.019380        0.000000             0.000000
# ...

# %%
sns.histplot(df4['area_worst'])
# Out:
# <Axes: xlabel='area_worst', ylabel='Count'>

# %%
sns.histplot(df4['area_mean'])
# Out:
# <Axes: xlabel='area_mean', ylabel='Count'>

# %%
Q1 , Q2 = df4['area_mean'].quantile([0.01,0.99])
Q1,Q2
# Out:
# (247.068, 1455.9599999999964)

# %%
df5 = df4[(df4['area_mean'] <= Q2) &  (df4['area_mean'] >= Q1)]

# %%
df5.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   521.000000    521.000000      521.000000   521.000000
# mean     13.975336     19.190787       90.868580   629.795202
# std       2.952294      3.958384       20.318348   278.104466
# min       9.029000     10.940000       58.790000   248.700000
# 25%      11.800000     16.210000       76.090000   428.000000
# 50%      13.340000     18.800000       86.180000   546.400000
# 75%      15.490000     21.590000      102.500000   747.200000
# max      21.610000     30.620000      144.400000  1407.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       521.000000        521.000000      521.000000           521.000000
# mean          0.096066          0.102337        0.084287             0.046756
# std           0.013875          0.050474        0.072197             0.034350
# min           0.062510          0.019380        0.000000             0.000000
# ...

# %%
sns.histplot(df5['area_mean'])
# Out:
# <Axes: xlabel='area_mean', ylabel='Count'>

# %%
df5.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   521.000000    521.000000      521.000000   521.000000
# mean     13.975336     19.190787       90.868580   629.795202
# std       2.952294      3.958384       20.318348   278.104466
# min       9.029000     10.940000       58.790000   248.700000
# 25%      11.800000     16.210000       76.090000   428.000000
# 50%      13.340000     18.800000       86.180000   546.400000
# 75%      15.490000     21.590000      102.500000   747.200000
# max      21.610000     30.620000      144.400000  1407.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       521.000000        521.000000      521.000000           521.000000
# mean          0.096066          0.102337        0.084287             0.046756
# std           0.013875          0.050474        0.072197             0.034350
# min           0.062510          0.019380        0.000000             0.000000
# ...

# %%
sns.histplot(df5['compactness_worst'])
# Out:
# <Axes: xlabel='compactness_worst', ylabel='Count'>

# %%
Q1 , Q2 = df5['compactness_worst'].quantile([0.01,0.99])
Q1,Q2
# Out:
# (0.049696, 0.7878599999999991)

# %%
df6 = df5[(df5['compactness_worst'] <= Q2) &  (df5['compactness_worst'] >= Q1)]

# %%
df6.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   509.000000    509.000000      509.000000   509.000000
# mean     13.993969     19.138114       90.976916   631.667583
# std       2.957332      3.931047       20.335257   278.659345
# min       9.029000     10.940000       58.790000   248.700000
# 25%      11.800000     16.170000       75.890000   428.000000
# 50%      13.400000     18.770000       86.600000   552.400000
# 75%      15.610000     21.580000      102.600000   758.600000
# max      21.610000     29.970000      144.400000  1407.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       509.000000        509.000000      509.000000           509.000000
# mean          0.096032          0.101516        0.083350             0.046627
# std           0.013547          0.047929        0.070272             0.033962
# min           0.064290          0.026750        0.000000             0.000000
# ...

# %%
sns.histplot(df6['compactness_worst'])
# Out:
# <Axes: xlabel='compactness_worst', ylabel='Count'>

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 509 entries, 1 to 566
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                509 non-null    object
#  1   radius_mean              509 non-null    float64
#  2   texture_mean             509 non-null    float64
#  3   perimeter_mean           509 non-null    float64
#  4   area_mean                509 non-null    float64
#  5   smoothness_mean          509 non-null    float64
#  6   compactness_mean         509 non-null    float64
#  7   concavity_mean           509 non-null    float64
#  8   concave points_mean      509 non-null    float64
#  9   symmetry_mean            509 non-null    float64
#  10  fractal_dimension_mean   509 non-null    float64
#  11  radius_se                509 non-null    float64
#  12  texture_se               509 non-null    float64
#  13  perimeter_se             509 non-null    float64
# ...

# %%
dummy_cols = pd.get_dummies(df6['diagnosis'],drop_first=True,dtype=int)

# %%
final0 = pd.concat([df6,dummy_cols], axis= 'columns')

# %%
final0.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 4         M        20.29         14.34          135.10     1297.0
# 5         M        12.45         15.70           82.57      477.1
# 6         M        18.25         19.98          119.60     1040.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 4          0.10030           0.13280          0.1980              0.10430
# 5          0.12780           0.17000          0.1578              0.08089
# 6          0.09463           0.10900          0.1127              0.07400
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
final = final0.drop('diagnosis',axis='columns')

# %%
final.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
# 6        18.25         19.98          119.60     1040.0          0.09463
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 4           0.13280          0.1980              0.10430         0.1809
# 5           0.17000          0.1578              0.08089         0.2087
# 6           0.10900          0.1127              0.07400         0.1794
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
X = final.drop('M',axis='columns')
y = final['M']

# %%
from sklearn.preprocessing import StandardScaler 
scalling = StandardScaler()

# %%
X_scaled = scalling.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 2.22582425, -0.34837027,  2.06362412, ...,  1.2288453 ,
#         -0.2413375 ,  0.36378181],
#        [ 1.92796598,  0.53776099,  1.92087436, ...,  2.18170568,
#          1.23650566,  0.2748567 ],
#        [ 2.13105116, -1.22176976,  2.17191703, ...,  0.83599936,
#         -0.90234267, -0.39208168],
#        ...,
#        [ 2.34429061,  1.515561  ,  2.56078705, ...,  2.36893438,
#          0.0651908 ,  0.96340882],
#        [ 2.07689512,  2.32020892,  1.97994323, ...,  0.84101441,
#         -0.54615336, -1.03493618],
#        [ 0.88207729,  2.2769209 ,  0.85271242, ...,  0.48996059,
#         -1.15236017, -0.30439164]])

# %%
from sklearn.model_selection import train_test_split 
X_scaled_train , X_scaled_test,y_train , y_test = train_test_split(X_scaled,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_scaled_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_scaled_test,y_test)
# Out:
# 1.0

# %%
y_pred = model.predict(X_scaled_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
cn = confusion_matrix(y_pred,y_test)
cn
# Out:
# array([[72,  0],
#        [ 0, 30]])

# %%
import seaborn as sns 
sns.heatmap(cn,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split 
X_train , X_test,y_train , y_test = train_test_split(X,y,test_size=0.2)

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.9607843137254902
